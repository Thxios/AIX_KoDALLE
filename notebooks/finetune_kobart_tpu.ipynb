# %%
# !pip install cloud-tpu-client https://storage.googleapis.com/tpu-pytorch/wheels/colab/torch_xla-1.11-cp37-cp37m-linux_x86_64.whl
# !pip install pandas
# !pip install transformers
# !pip install datasets
# !pip install streamlit
# !pip install wandb
# !pip install webdataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 152.9 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 57 kB 3.2 MB/s
# ...
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 1.12.11
#     Uninstalling google-api-python-client-1.12.11:
#       Successfully uninstalled google-api-python-client-1.12.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# earthengine-api 0.1.311 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 1.8.0 which is incompatible.
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !cp -r /content/drive/MyDrive/data_kodalle /content/data

# %%
# !cp /content/drive/MyDrive/tpu_train_scripts.tar.gz /content/train_scripts.tar.gz
# !tar -zxf train_scripts.tar.gz

# %%
# api key : 7c28b4cad7b30138a97d79d3e972a9a483ee42ac
# !wandb init
# Out:
# Let's setup this directory for W&B!
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Which team should we use?
# wandb: (1) hyunwoo3235
# wandb: (2) aix
# wandb: (3) Manual entry
# wandb: Enter your choice: 1
# wandb: You chose 'hyunwoo3235'
# wandb: Which project should we use?
# wandb: (1) huggingface
# wandb: (2) aix
# wandb: (3) uncategorized
# wandb: (4) stylevits
# wandb: (5) vits
# wandb: (6) hifigan
# wandb: (7) Create New
# wandb: Enter your choice: 1
# wandb: You chose 'huggingface'
# This directory is configured!  Next, track a run:
# * In your training script:
#     import wandb
#     wandb.init(project="huggingface")
# * then `python <train.py>`.

# %%
# !python xla_spawn.py --num_cores 8 \
    train.py \
    --model_name_or_path gogamza/kobart-base-v2 \
    --train_file data/train.json \
    --validation_file data/test.json \
    --do_train \
    --per_device_train_batch_size 64 \
    --gradient_accumulation_steps 2 \
    --learning_rate 5e-4 \
    --run_name "Adafactor-1024-0.0005" \
    --dataloader_drop_last True \
    --max_steps 100000 \
    --warmup_steps 1000 \
    --logging_steps 10 \
    --optim adafactor \
    --output_dir "/content/drive/MyDrive/kodalle/1024-0.0005" \
    --save_steps 1000 \
    --save_total_limit 3
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  36% 36169/100000 [5:54:41<58:49:11,  3.32s/it]
#  36% 36170/100000 [5:54:45<62:30:14,  3.53s/it]
#
#  36% 36170/100000 [5:54:46<62:30:14,  3.53s/it]{'loss': 5.1745, 'learning_rate': 0.00032237373737373736, 'epoch': 66.73}
#
#  36% 36171/100000 [5:54:49<67:15:48,  3.79s/it]
#  36% 36172/100000 [5:54:53<67:54:54,  3.83s/it]
#  36% 36173/100000 [5:54:56<62:17:09,  3.51s/it]
#  36% 36174/100000 [5:54:59<59:58:57,  3.38s/it]
#  36% 36175/100000 [5:55:02<59:06:05,  3.33s/it]
#  36% 36176/100000 [5:55:05<59:54:50,  3.38s/it]
#  36% 36177/100000 [5:55:08<56:53:43,  3.21s/it]
#  36% 36178/100000 [5:55:13<62:14:23,  3.51s/it]
#  36% 36179/100000 [5:55:15<55:10:52,  3.11s/it]
#  36% 36180/100000 [5:55:17<52:28:16,  2.96s/it]
#
#  36% 36180/100000 [5:55:19<52:28:16,  2.96s/it]{'loss': 5.1676, 'learning_rate': 0.00032232323232323233, 'epoch': 66.75}
#
#  36% 36181/100000 [5:55:22<61:28:15,  3.47s/it]
#  36% 36182/100000 [5:55:27<67:09:16,  3.79s/it]
# ...

# %%
# !cp -r /content/wandb /content/drive/MyDrive/
